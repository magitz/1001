# %% [markdown]
# <a href="https://colab.research.google.com/github/magitz/1001/blob/master/02_emotion_is_the_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Emotion is the key
#
# This notebook creates a small program that takes an input of an emotion and outputs the title of a song that matches that emotion.
#
# As input data, it links to a Google Sheet with the data collected from a Google Form where users enter songs and artits they associate with different emotions.

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# The ID of the Google Sheet and the gid of the worksheet
sheet_id = "1A8YVKxvEnF9OFdePQqdyBwzUG_o0n-WmJPprzdz74JU"
worksheet_gid = "1445035333"

# Construct the URL to download the Google Sheet as a CSV file
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={worksheet_gid}"

# Download the Google Sheet as a CSV file
df = pd.read_csv(url)

# Save the DataFrame as a CSV file in the current directory
df.to_csv("output.csv", index=False)

# %%
df.head()
# Out:
#             Timestamp  \
# 0                 NaN
# 1  7/16/2024 13:42:09
# 2  7/16/2024 15:33:46
# 3  7/16/2024 15:38:10
# 4  7/16/2024 15:42:21
#
#   What's the name of a song you think of when you think "Angry"?  \
# 0                                                NaN
# 1                                Goodbye Declaration
# 2                                     New Magic Wand
# 3                                           Euphoria
# 4                                            traitor
#
#   What's the name of the artist for your "Angry" song?  \
# 0                                                NaN
# 1                                            Chinozo
# 2                                  Tyler the Creator
# 3                                    Kendricks Lamar
# 4                                    Olivia Rodrigo
#
#   What's the name of a song you think of when you think "Fear"?  \
# 0                                                NaN
# 1                                Four Seasons Winter
# 2                                            Redbone
# 3                                   Jaws theme song
# 4                                        In My Blood
#
#   What's the name of the artist for your "Fear" song?  \
# 0                                                NaN
# 1                                            Vivaldi
# 2                                   Childish Gambino
# 3                                      John Williams
# 4                                       Shawn Mendes
#
#   What's the name of a song you think of when you think "Happy"?  \
# 0                                                NaN
# 1                                           Carefree
# 2                                             Lucky
# 3                                          The Spins
# 4                                      Teenage Dream
#
#   What's the name of the artist for your "Happy" song?  \
# 0                                                NaN
# 1                                      Kevin Macleod
# 2                                       Kenyon Dixon
# 3                                         Mac Miller
# 4                                         Katy Perry
#
#   What's the name of a song you think of when you think "A Little Bored"?  \
# 0                                                NaN
# 1                                 You Belong With Me
# 2                                    Donny In Valdez
# 3                                          Singapore
# 4                                      Somebody Else
#
#   What's the name of the artist for your "A Little Bored" song?  \
# 0                                                NaN
# 1                                       Taylor Swift
# 2                                           Pale Jay
# 3                                         Ken Carson
# 4                                           The 1975
#
#   What's the name of a song you think of when you think "Sad"?  \
# 0                                                NaN
# 1                                     Yoru ni Kakeru
# 2                                           Easy Lee
# 3                                     Still the Same
# 4                                     Forever Winter
#
#   What's the name of the artist for your "Sad" song?  \
# 0                                                NaN
# 1                                            Yoasobi
# 2                                           Pale Jay
# 3                                            Autumn!
# 4                                       Taylor Swift
#
#   What's the name of a song you think of when you think "Surprise"?  \
# 0                                                NaN
# 1                                Among Us Trap Remix
# 2                                              Karma
# 3                                     Happy Birthday
# 4                                          Riff off
#
#   What's the name of the artist for your "Surprise" song?  \
# 0                                                NaN
# 1                                              Leonz
# 2                                          Jojo Siwa
# 3          Patty Hill and Mildred J. Hill ( Sisters)
# 4                                    Pitch Perfect 2
#
#   What's the name of a song you think of when you think "Disgust"?  \
# 0                                                NaN
# 1                                          Bad Blood
# 2                                     Boys Aint Sh*t
# 3                                              Karma
# 4                                              Karma
#
#   What's the name of the artist for your "Disgust" song?
# 0                                                NaN
# 1                                       Taylor Swift
# 2                                           Saygrace
# 3                                          Jojo Siwa
# 4                                          Jojo Siwa

# %%
# Drop the first column of the DataFrame

df = df.drop(columns=["Timestamp"])

df.head()
# Out:
#   What's the name of a song you think of when you think "Angry"?  \
# 0                                                NaN
# 1                                Goodbye Declaration
# 2                                     New Magic Wand
# 3                                           Euphoria
# 4                                            traitor
#
#   What's the name of the artist for your "Angry" song?  \
# 0                                                NaN
# 1                                            Chinozo
# 2                                  Tyler the Creator
# 3                                    Kendricks Lamar
# 4                                    Olivia Rodrigo
#
#   What's the name of a song you think of when you think "Fear"?  \
# 0                                                NaN
# 1                                Four Seasons Winter
# 2                                            Redbone
# 3                                   Jaws theme song
# 4                                        In My Blood
#
#   What's the name of the artist for your "Fear" song?  \
# 0                                                NaN
# 1                                            Vivaldi
# 2                                   Childish Gambino
# 3                                      John Williams
# 4                                       Shawn Mendes
#
#   What's the name of a song you think of when you think "Happy"?  \
# 0                                                NaN
# 1                                           Carefree
# 2                                             Lucky
# 3                                          The Spins
# 4                                      Teenage Dream
#
#   What's the name of the artist for your "Happy" song?  \
# 0                                                NaN
# 1                                      Kevin Macleod
# 2                                       Kenyon Dixon
# 3                                         Mac Miller
# 4                                         Katy Perry
#
#   What's the name of a song you think of when you think "A Little Bored"?  \
# 0                                                NaN
# 1                                 You Belong With Me
# 2                                    Donny In Valdez
# 3                                          Singapore
# 4                                      Somebody Else
#
#   What's the name of the artist for your "A Little Bored" song?  \
# 0                                                NaN
# 1                                       Taylor Swift
# 2                                           Pale Jay
# 3                                         Ken Carson
# 4                                           The 1975
#
#   What's the name of a song you think of when you think "Sad"?  \
# 0                                                NaN
# 1                                     Yoru ni Kakeru
# 2                                           Easy Lee
# 3                                     Still the Same
# 4                                     Forever Winter
#
#   What's the name of the artist for your "Sad" song?  \
# 0                                                NaN
# 1                                            Yoasobi
# 2                                           Pale Jay
# 3                                            Autumn!
# 4                                       Taylor Swift
#
#   What's the name of a song you think of when you think "Surprise"?  \
# 0                                                NaN
# 1                                Among Us Trap Remix
# 2                                              Karma
# 3                                     Happy Birthday
# 4                                          Riff off
#
#   What's the name of the artist for your "Surprise" song?  \
# 0                                                NaN
# 1                                              Leonz
# 2                                          Jojo Siwa
# 3          Patty Hill and Mildred J. Hill ( Sisters)
# 4                                    Pitch Perfect 2
#
#   What's the name of a song you think of when you think "Disgust"?  \
# 0                                                NaN
# 1                                          Bad Blood
# 2                                     Boys Aint Sh*t
# 3                                              Karma
# 4                                              Karma
#
#   What's the name of the artist for your "Disgust" song?
# 0                                                NaN
# 1                                       Taylor Swift
# 2                                           Saygrace
# 3                                          Jojo Siwa
# 4                                          Jojo Siwa

# %%
# Replace Column Header Names with simpler names
df.columns = ['Angry', 'Angry_Artist',
              'Fear', 'Fear_Artist',
              'Happy', 'Happy_Artist',
              'Neutral', 'Neutral_Artist',
              'Sad', 'Sad_Artist',
              'Surprise', 'Surprise_Artist',
              'Disgust', 'Disgust_Artist'
              ]

df.head()
# Out:
#                  Angry       Angry_Artist                 Fear  \
# 0                  NaN                NaN                  NaN
# 1  Goodbye Declaration            Chinozo  Four Seasons Winter
# 2       New Magic Wand  Tyler the Creator              Redbone
# 3             Euphoria    Kendricks Lamar     Jaws theme song
# 4              traitor    Olivia Rodrigo           In My Blood
#
#         Fear_Artist          Happy   Happy_Artist             Neutral  \
# 0               NaN            NaN            NaN                 NaN
# 1           Vivaldi       Carefree  Kevin Macleod  You Belong With Me
# 2  Childish Gambino         Lucky    Kenyon Dixon     Donny In Valdez
# 3     John Williams      The Spins     Mac Miller           Singapore
# 4      Shawn Mendes  Teenage Dream     Katy Perry       Somebody Else
#
#   Neutral_Artist             Sad    Sad_Artist             Surprise  \
# 0            NaN             NaN           NaN                  NaN
# 1   Taylor Swift  Yoru ni Kakeru       Yoasobi  Among Us Trap Remix
# 2       Pale Jay        Easy Lee      Pale Jay                Karma
# 3     Ken Carson  Still the Same       Autumn!       Happy Birthday
# 4       The 1975  Forever Winter  Taylor Swift            Riff off
#
#                              Surprise_Artist         Disgust Disgust_Artist
# 0                                        NaN             NaN            NaN
# 1                                      Leonz       Bad Blood   Taylor Swift
# 2                                  Jojo Siwa  Boys Aint Sh*t       Saygrace
# 3  Patty Hill and Mildred J. Hill ( Sisters)           Karma      Jojo Siwa
# 4                            Pitch Perfect 2           Karma      Jojo Siwa

# %%
df
# Out:
#                   Angry              Angry_Artist                  Fear  \
# 0                   NaN                       NaN                   NaN
# 1   Goodbye Declaration                   Chinozo   Four Seasons Winter
# 2        New Magic Wand         Tyler the Creator               Redbone
# 3              Euphoria           Kendricks Lamar      Jaws theme song
# 4               traitor           Olivia Rodrigo            In My Blood
# 5                Anger           Sleeping at last  You're somebody else
# 6                   RIP             Playboi Carti          Monster Mash
# 7             Love Sosa                Chief Keef          Monster Mash
# 8            OD CRASHIN                  Baby Kia      NIGHTS LIKE THIS
# 9                   NaN                       NaN        The Big Afraid
# 10                  NaN                       NaN             Fall Away
# 11            Bad Blood              Taylor Swift              Thriller
# 12        Only One King            Tommee Profitt      What's Up Danger
# 13   be quiet and drive                 deaftones       Halloween theme
# 14        get him back!            Olivia Rodrigo             About You
# 15          Alien Blues                  Vundabur          No Surprises
# 16                  360               Charlie xcx        Black Out Days
# 17             Dear God                  Confetti      Into the Unknown
# 18     Before he cheats          Carrie Underwood              Thriller
# 19  killing in the name  rage against the machine      Paranoid Android
#
#                Fear_Artist                               Happy  \
# 0                      NaN                                 NaN
# 1                  Vivaldi                            Carefree
# 2         Childish Gambino                              Lucky
# 3            John Williams                           The Spins
# 4             Shawn Mendes                       Teenage Dream
# 5               flora cash  BEAUTIFUL THINGS WE SAW ON APRIL 1
# 6                    Goofy                                Surf
# 7                    Goofy                        HVN ON EARTH
# 8            The Kid LAROI                          NEVER LEFT
# 9           65daysofstatic                                 NaN
# 10       twenty one pilots                                 NaN
# 11         Michael Jackson        Happy (From Despicable Me 2)
# 12  Blackway, Black Caviar                     I Ain't Worried
# 13          john carpenter                               happy
# 14                    1975                        Talk to much
# 15               Radiohead                 You Belong With Me
# 16              Phantogram                        Passionfruit
# 17          Thomas Sanders          So Alright, Cool, Whatever
# 18         Michael Jackson                  Walking on a Dream
# 19               Radiohead                     Good Vibrations
#
#          Happy_Artist                   Neutral           Neutral_Artist  \
# 0                 NaN                       NaN                      NaN
# 1       Kevin Macleod        You Belong With Me             Taylor Swift
# 2        Kenyon Dixon           Donny In Valdez                 Pale Jay
# 3          Mac Miller                 Singapore               Ken Carson
# 4          Katy Perry             Somebody Else                 The 1975
# 5       Tom Rosenthal      It's Called Freefall  Rainbow Kitten Surprise
# 6          Young Thug               Green Room                Ken Carson
# 7           Lil Tecca                      Flex            Playboi Carti
# 8           Lil Tecca             Back On My BS              BigXthaPlug
# 9                 NaN     im So Bored Oh My God                    AZALI
# 10                NaN                       NaN                      NaN
# 11  Pharrell Williams             The Lazy Song               Bruno Mars
# 12        OneRepublic                Heat Waves            Glass Animals
# 13  Pharrell Williams                   only if               steve lacy
# 14               COIN                Feels Like            Gracie Abrams
# 15       Taylor Swift            Wasted Summers                   juju<3
# 16              Drake                  Pyramids              Frank Ocean
# 17     The Happy Fits          moonlight sonata               Beethoven
# 18  Empire Of the Sun     My Love Mine All Mine                   Mitski
# 19         Beach Boys  static sound brown noise                      NaN
#
#                     Sad      Sad_Artist              Surprise  \
# 0                   NaN             NaN                   NaN
# 1        Yoru ni Kakeru         Yoasobi   Among Us Trap Remix
# 2              Easy Lee        Pale Jay                 Karma
# 3        Still the Same         Autumn!        Happy Birthday
# 4        Forever Winter    Taylor Swift             Riff off
# 5                  July      Noah Cyrus          Possum Queen
# 6          see the real       21 savage         Drip or Drown
# 7            Headlines            Drake              Overseas
# 8                   505  Arctic Monkeys              Pressure
# 9                   NaN             NaN                   NaN
# 10      Halcon Memories   James Primate                   NaN
# 11              Grenade      Bruno Mars       Happy Birthday
# 12  Mockingbird (Clean)          Eminem         Can't Hold Us
# 13             let down       radiohead    Baby one more time
# 14           Mirrorball    Taylor Swift                 Limbo
# 15            Two Birds  Regina Spektor          Viva La Vida
# 16           Space Song     Beach House  Pursuit Of Happiness
# 17          happy pills        weathers     Surprise Surprise
# 18                 July      Noah Cyrus        Happy Birthday
# 19          mockingbird          Eminem       Jack In The Box
#
#                               Surprise_Artist         Disgust  \
# 0                                         NaN             NaN
# 1                                       Leonz       Bad Blood
# 2                                   Jojo Siwa  Boys Aint Sh*t
# 3   Patty Hill and Mildred J. Hill ( Sisters)           Karma
# 4                             Pitch Perfect 2           Karma
# 5                     Rainbow Kitten Surprise   Drive Through
# 6                                       Gunna        Up off X
# 7                                  Ken Carson           PDBMH
# 8                                BossMan Dlow         Shibuya
# 9                                         NaN          Lavish
# 10                                        NaN             NaN
# 11                              Stevie Wonder       Boomerang
# 12                                 Macklemore          Reject
# 13                             Britney Spears          karma
# 14                               Daddy Yankke        The girl
# 15                                   Coldplay             NaN
# 16                                   Kid Cudi      Baby Shark
# 17                                john lennon           Karma
# 18                          Happy Birthday TA     Barbie Girl
# 19                                        NaN             NaN
#
#             Disgust_Artist
# 0                      NaN
# 1             Taylor Swift
# 2                 Saygrace
# 3                Jojo Siwa
# 4                Jojo Siwa
# 5                 Weird Al
# 6                     Yeat
# 7               Ken Carson
# 8   Ski Mask The Slump God
# 9        twenty one pilots
# 10                     NaN
# 11               Jojo Siwa
# 12               Green Day
# 13               jojo siwa
# 14              Charli xcx
# 15                     NaN
# 16                Pinkfong
# 17               JoJo Siwa
# 18                    Aqua
# 19                     NaN

# %%
# Create a Function that takes the user input of an emotion and output a
# random song title with it's artist that matches that emotion

def lookup_song(emotion):
    # Format the emotion to have the first letter capitalized
    emotion = emotion.capitalize()

    # Set to 'nan ' to deal with missing titles/artists
    song_title = 'nan '
    artist = 'nan '

    # Check if the emotion is in the DataFrame
    if emotion not in df.columns:
        return "Invalid emotion! Please enter one of the following emotions: Angry, Fear, Happy, Neutral, Sad, Surprise, Disgust"

    # We don't want nan values for songs or artists
    while song_title == 'nan ' or artist == 'nan ':
      # Select a random value from 0 to len(df)
      random_index = np.random.randint(0, len(df))

      # Select the song title from the selected emotion
      song_title = df[emotion][random_index]

      # Get the artist for the song
      artist = df[emotion + "_Artist"][random_index]

    # Return the song title, artist and emotion
    return song_title, artist, emotion

# %%
def emotion_input_test(emotion):
    # Test the lookup_song function
    song_title, artist, emotion = lookup_song(emotion)
    print(f"The song title that matches the emotion '{emotion}' is: {song_title} by {artist}")

# Test the lookup_song function
emotion_input_test('sad')
# Out:
# The song title that matches the emotion 'Sad' is: Grenade by Bruno Mars
